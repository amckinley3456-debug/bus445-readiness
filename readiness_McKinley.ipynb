# %%
import sys
print(sys.executable)
# Out:
# C:\Users\amcki\anaconda3\python.exe

# %%
def mean_and_max(numbers):
    mean_value = sum(numbers) / len(numbers)
    max_value = max(numbers)
    return mean_value, max_value

my_numbers = [4, 8, 15, 16, 23, 42]
avg, top = mean_and_max(my_numbers)
print(f"Mean: {avg}, Max: {top}")
# Out:
# Mean: 18.0, Max: 42

# %% [markdown]
# One difference I noticed is that in Jupyter I can run cells out of order and see each result immediately, while in VS Code the whole script runs top to bottom at once in the terminal.
